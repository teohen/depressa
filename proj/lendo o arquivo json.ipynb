# %%
import pandas as pd
import json 

with open('fmom.json', 'r') as fp:
    d = json.load(fp)

# %%
lis = list()
for a in d:
    lis.append(json.loads(a))

# %%
for b in lis:
    print(b['text'])
# Out:
# gastar dinheiro com tudo que vê*** https://t.co/OBwKs7zJb0
# eu vejo gente postando indireta, mas a indireta serve mais pra ela do que pra outra, tem dó
# RT @Thayna_rodrigx: Gente eu vejo mulheres que ficam perfeitas de rabo de cavalo, vão pra festas e tudo, EU DE RABO DE CAVALO PAREÇO UM JEG…
# RT @ajulialacerda: olho pra uns garotos e penso
# poxa uma pena namoro evangelístico não funcionar
# esse sanduiche do bodock não existe
# não sei o que é pior, criança mimada de 5 anos ou criança mimada de 25 anos
# RT @leviqueiroz_: Gente isso é muito verdade. O amor não é fingido, assim como a oração. O amor é paciente, assim como a oração. O amor tud…
# @Marina_leao15 @ahmovibe KKKKKK
# RT @DeputadoFederal: RECADO DO LULA
#
# @LulaOficial está livre para ajudar o Brasil a se recuperar da loucura pela qual o nosso país está pas…
# cês deve achar né https://t.co/Ncolj8e212
# ...
